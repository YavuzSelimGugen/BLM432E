# %%
import numpy as np 
import pylab 
import scipy.stats as stats

# %%
qq = np.random.normal(loc = 20, scale = 2, size=9)   
print(qq)
# Out:
# [19.62934246 18.96032643 21.97858947 20.784034   20.34182075 19.9831901
#  20.04614209 18.56587414 18.93129849]

# %%
qq.sort()
print(qq)
# Out:
# [18.56587414 18.93129849 18.96032643 19.62934246 19.9831901  20.04614209
#  20.34182075 20.784034   21.97858947]

# %%
stats.probplot(qq, dist="norm", plot=pylab)
pylab.show()
